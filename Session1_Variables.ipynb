# %% [markdown]
# # **Session 1 :- Variables**

# %%
# What is a Variable?
# Imagine you have a box and you put something inside it.

# Here:
# age → box name
# 22 → value inside the box

# Interview Definition:- A variable is a name given to a memory location that stores a value.
# Simple Definition:- A variable is a container used to store data.

# %% [markdown]
# **Variables Store Values**

# %%
name = "Janvi"

# Variable name = name
# Stored value = "Janvi"
# A variable is simply a label attached to a value.

# %%
n1= 100  #100 is stored in a variable called:n1
n1
# Out:
# 100

# %%
n1=200
n1
# Out:
# 200

# %%
# A variable can be reassigned.
# Python always keeps the latest value.

age=20
age=30
age=40
age
# Out:
# 40

# %% [markdown]
# **Variable Naming Rules**

# %%
#valid:-

number1 = 100
NUMBER1 = 200
NUMber1 = 300
number123 = 400
number_one = 900

# %%
# Invalid:-

123number = 500   #Starts with number
number*one = 600  #Special character
number%one = 700  #Special character 
number one = 800  #Space
if = 2000         #Keyword
"number" = 1000   #String cannot be variable

# %%
number1 = 100
NUMBER1 = 200
print(number1)
print(NUMBER1)
#These are different variables.
# Out:
# 100
# 200

# %%
number1=100 #black is variable other than it all wrong 
NUMBER1=200
NUMber1=300
number123=400
123number=500  #starting with number is not allowed
number*one=600 #special character are not allowed
number%one=700  #special character are not allowed
number one=800 #space is invalid
number_one=900   #underscore is valid
"number"=1000  
if=2000  #keywords are not allowed
else=500 #keywords are not allowed
max=900

# %%
areaoftriangle=600
area_of_triangle=600  #better to write like this for better understanding

# %% [markdown]
# **Keywords**

# %%
if
else
for
while
True 
False

# These are reserved words.
# They cannot be used as variable names.

# %%
if=900   #Produces:SyntaxError
# Out:
#   Cell In[8], line 1
#     if=900   #Produces:SyntaxError
#       ^
# SyntaxError: invalid syntax

# %%
if #bold 
else
sum #not bold is mathematics family

# %%
black ===================== number=600 #works
green in bold == True = 800 #fail
green ======== max = 123 #works
red ===== "number" #fail

# %% [markdown]
# **Built-in Functions**

# %%
sum()
max()
min()
len()

# %%
min
# Out:
# <function min>

# %%
l=[10,20,30]
sum(l)
# Out:
# 60

# %%
#inbuild functions
max(l)
# Out:
# 30

# %%
min(l)
# Out:
# 10

# %%
len(l)
# Out:
# 3

# %%
# Avoid using:

# sum=500
# min=900
# max=700

# This works.
# But it's not a good practice.
# Why?
# Because now:
# max([10,20,30])
# may stop working properly.
# This is called shadowing built-in functions.

# %%
n1=100
n2=200
n1
n2
# Out:
# 200

# %%
n1=100
n2=200
print(n1) # if i want to see always use "print"
print(n2)
# Out:
# 100
# 200

# %%
n1=100
n2=300
if=400 #fails 
n3=700
# Out:
#   Cell In[20], line 3
#     if=400
#       ^
# SyntaxError: invalid syntax

# %%
a=10
b=20
a,b=30
a,b=40,50
a=50,60

# %%
a=10
a
# Out:
# 10

# %%
b=20
b
# Out:
# 20

# %%
a,b=30 # fails 
        #error:-cannot unpack non-iterable int object
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 a,b=30
#
# TypeError: cannot unpack non-iterable int object

# %%
a,b=40,50
a,b
# Out:
# (40, 50)

# %%
a=50,60   #Tuple Assignment:- This creates a tuple.
a
# Out:
# (50, 60)
