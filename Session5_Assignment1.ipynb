# %% [markdown]
# # **Session 5**
#
# **Assignment:- 1**

# %% [markdown]
# **Python programming question that requires the student to take input, perform calculations, and display results.**

# %%
# Take Input
#     ↓
# Type Cast
#     ↓
# Apply Formula
#     ↓
# Store Result
#     ↓
# Display Result

# %%
#WAP calculate avg of 3 numbers

number1=int(input('enter a number1:'))
number2=int(input('enter a number2:'))
number3=int(input('enter a number3:'))
avg=(number1+number2+number3)/3
avg
# Out:
# enter a number1: 10
# enter a number2: 20
# enter a number3: 30
# 20.0

# %%
#WAP calculate area of circle
#formula: 3.14*r*r

radius=int(input('enter a radius of circle:'))
area_of_circle= 3.14*radius*radius
area_of_circle
# Out:
# enter a radius of circle: 5
# 78.5

# %%
#WAP calculate area of rectangle
#formula: length*breadth

length=int(input('enter a length:'))
breadth=int(input('enter a breadth:'))
area_of_rectangle=length*breadth
area_of_rectangle
# Out:
# enter a length: 10
# enter a breadth: 20
# 200

# %%
#WAP calculate area of square
#formula: side*side

side=int(input('enter a side:'))
area_of_square=side*side
area_of_square
# Out:
# enter a side: 5
# 25

# %%
#WAP calculate perimeter of rectangle
#formula: 2*(l+w)

length=int(input('enter a length:'))
width=int(input('enter a width:'))
perimeter_of_rectangle=2*(length+width)
perimeter_of_rectangle
# Out:
# enter a length: 10
# enter a width: 20
# 60

# %%
#WAP calculate perimeter of square
#formula: 4s

side=int(input('enter a side:'))
perimeter_of_square=4*side
perimeter_of_square
# Out:
# enter a side: 10
# 40

# %%
#WAP calculate area of triangle
#formula: 1/2 × b × h

height=int(input('enter a height:'))
breadth=int(input('enter a breadth:'))
area_of_triangle=1/2*breadth*height
area_of_triangle
# Out:
# enter a length: 10
# enter a breadth: 10
# 50.0

# %%
#WAP calculate circumference of circle
#formula: 2*3.14*r

radius=int(input('enter a radius of circle:'))
circumference_of_circle= 2*3.14*radius
circumference_of_circle

# 31.400000000000002
# This happens because computers store decimal numbers approximately in memory.
# Nothing is wrong.
# This is called:Floating Point Precision
# Out:
# enter a circumference of circle: 5
# 31.400000000000002

# %%
#WAP calculate Simple Intrest
#formula: SI = (P × R × T)/100

Principal=int(input('enter the principal:'))
Rate=int(input('enter the Rate:'))
Time=int(input('enter the Time:')) 
Simple_Intrest = (Principal*Rate*Time)/100
Simple_Intrest
# Out:
# enter the principle: 10000
# enter the Rate: 5
# enter the Time: 3
# 1500.0

# %%
#WAP calculate compound Intrest
#formula:CI = P(1 + R/100)^T − P

Principal=int(input('enter the Principal:'))
Rate=int(input('enter the Rate:'))
Time=int(input('enter the Time:'))
Compound_Intrest = Principal*(1 + Rate/100)**Time-Principal
Compound_Intrest
# Out:
# enter the Principle: 5000
# enter the Rate: 8
# enter the Time: 2
# 832.0000000000009

# %%
#WAP calculate percentage
#formula:Percentage = (Obtained/Total) × 100

Obtained=int(input('enter the percentage Obtained :'))
Total=int(input('enter the total :'))
Percentage = (Obtained/Total)*100
Percentage
# Out:
# enter the percentage Obtained : 10
# enter the total : 20
# 50.0

# %%
#WAP calculate Celsius to Fahrenheit
#formula:F = (C × 9/5) + 32

C=int(input('enter the Celsius:'))
F = (C *9/5) + 32
F
# Out:
# enter the Celsius: 50
# 122.0

# %%
#WAP calculate Fahrenheit to Celsius
#formula:C = (F − 32) × 5/9

F=int(input('enter the Fahrenheit :'))
C = (F-32)*5/9
C
# Out:
# enter the Fahrenheit : 50
# 10.0

# %%
#WAP calculate Distance Speed Time
#formula: Distance = Speed × Time

Speed=int(input('enter the Speed:'))
Time=int(input('enter the Time:'))
Distance_Speed_Time = Speed*Time
Distance_Speed_Time
# Out:
# enter the Speed: 100
# enter the Time: 20
# 2000

# %%
#WAP calculate BMI Calculator
#formula: BMI = Weight/(Height²)

weight = float(input('Enter weight in kg: '))
height_cm = float(input('Enter height in cm: '))
height_m = height_cm/100
BMI = weight/(height_m*height_m)
print(BMI)                       # BMI formula requires height in meters
# Out:
# enter the Weight(kg): 45
# enter the Height(cm): 154
# 0.0018974531961544949

# %%
#WAP calculate Volume of Cube
#formula: V = s³

side=int(input('enter the side:'))
Volume_of_Cube = side*side*side
Volume_of_Cube
# Out:
# enter the side: 10
# 1000

# %%
#WAP calculate Volume of Cuboid
#formula: V = l × w × h

length=int(input('enter the length:'))
weidth=int(input('enter the weidth:'))
height=int(input('enter the height:'))
Volume_of_Cuboid = length*weidth*height
Volume_of_Cuboid
# Out:
# enter the length: 10
# enter the weidth: 10
# enter the height: 10
# 1000

# %%
#WAP calculate Volume of Cylinder
#formula: V = πr²h

radius=int(input('enter the radius:'))
height=int(input('enter the height:'))
Volume_of_Cylinder = 3.14*radius*radius*height
Volume_of_Cylinder
# Out:
# enter the radius: 10
# enter the height: 20
# 6280.0

# %%
#WAP calculate Profit or Loss
#formula: Profit = SP − CP

SP=int(input('enter the SP:'))
CP=int(input('enter the CP:'))
Profit = SP-CP
Profit
# Out:
# enter the SP: 200
# enter the CP: 100
# 100

# %%
#WAP calculate Electricity Bill
#formula: Bill = Units × Rate

Units=int(input('enter the Units:'))
Rate=int(input('enter the Rate:'))
Electricity_Bill = Units*Rate
Electricity_Bill
# Out:
# enter the Units: 10
# enter the Rate: 20
# 200

# %%
# int(input())
# Answer:
# Because input() returns a string and int() converts it into an integer for calculations.

# %%
# What is the difference between?
# input()  and  int(input())
# Answer:
        # input() → returns string
        # int(input()) → returns integer

# %%
# Why is type casting important?
# Answer:
# Type casting allows us to convert one datatype into another so that required operations can 
# be performed.
