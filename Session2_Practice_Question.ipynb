# %% [markdown]
# # **Session 2 :- Practice Question**

# %%
# These questions teach you how to:

# Store values in variables
# Perform calculations
# Store results in another variable
# Understand formulas
# Build logic step-by-step

# %%
#WAP avg of three numbers 
# Average means: Sum of all numbers ÷ Number of values

number1=10
number2=20
number3=30
avg=(number1+number2+number3)/3
avg
# Out:
# 20.0

# %%
#WAP calculate area of circle
#formula: 3.14*r*r
# Radius = Distance from center of circle to boundary.

radius=15
area_of_circle= 3.14*radius*radius
area_of_circle
# Out:
# 706.5

# %%
#WAP calculate area of rectangle
#formula: length*breadth

length=100
breadth=200
area_of_rectangle=length*breadth
area_of_rectangle
# Out:
# 20000

# %%
#WAP calculate area of square
#formula: side*side

side=40
area_of_square=side*side
area_of_square
# Out:
# 1600

# %%
#WAP calculate area of triangle
#formula: 0.5*breadth*height  or   # Area of triangle = 1/2 × base × height

height=10
breadth=20
area_of_triangle=0.5*breadth*height
area_of_triangle
# Out:
# 100.0

# %%
#WAP calculate perimeter of rectangle
#formula: 2*(l+b)
# Perimeter means: Total distance around a shape.

l=10
b=20
perimeter_of_rectangle=2*(l+b)
perimeter_of_rectangle
# Out:
# 60
