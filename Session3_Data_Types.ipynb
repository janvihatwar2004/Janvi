# %% [markdown]
# # **Session 3 :- Data Types**

# %% [markdown]
# A Data Type tells Python what kind of value is stored in a variable.

# %%
# Interview Definition:-
    
# A Data Type is a classification that specifies what type of value a variable can store 
# and what operations can be performed on it.

# %%
# Real Life Example

# Think of a kitchen.
    
# | Item          | Data Type |
# | ------------- | --------- |
# | Sugar         | int       |
# | Milk Quantity | float     |
# | Name          | string    |
# | ON/OFF Switch | boolean   |

# %% [markdown]
# **Data Types**
#
# - int
#
# - float
#
# - str      #(string)
#
# - bool     #(boolean)
#
# - complex
#
# - list
#
# - tuple
#
# - dict      #(dictionary)
#
# - set
#
# - frozenset
#
# - bytes
#
# - bytearray
#
# - range
#
# - None

# %% [markdown]
# **1. Integer (int)**

# %%
# A whole number without decimal point.
# example:- 
# 10
# 20
# -50
# 1000

# %%
n1=20  ## integer stores whole numbers

# %%
# sum()
# max()
# min()
# len()
# print()    #CTRL+/ for commenting many line at once
type(n1)
# Out:
# int

# %% [markdown]
# **2. Float**

# %%
# A number containing a decimal point.

# Examples:
# 10.5
# 20.8
# 100.0

# %%
n2=100.5   # float stores decimal values
type(n2)
# Out:
# float

# %% [markdown]
# **Exponential Numbers**

# %%
10e2  #scientific notation (10 × 10²)
# Out:
# 1000.0

# %%
10e1 #100.0  10*10
10e2 #1000.0 10*100   
10e3 #10000.0 10*1000
10e4
# Out:
# 100000.0

# %%
2e3 # 2* 1000
# Out:
# 2000.0

# %%
10e+1,10e+2,10e+3
# Out:
# (100.0, 1000.0, 10000.0)

# %%
10e1==10e+1
# Out:
# True

# %%
10e+1 #10*10 #10e-1=10/10
10e+2 #10*100 #10e-2=10/100  #e+2 means:Move decimal 2 places right

# %%
10e-1   # e-1 :- Move decimal 2 places left
# Out:
# 0.1

# %%
10e-2
# Out:
# 0.1

# %%
1.31155816e+02,1.98781515e+01
# Out:
# (131.155816, 19.8781515)

# %% [markdown]
# **3. Strings**

# %%
# A string is text enclosed inside quotes.
# Examples:
# 'Janvi'
# "Janvi"
# Both are strings.

# Interview Definition:-
# A string is a sequence of characters enclosed within single quotes, double quotes, or triple quotes.

# %%
# strings are red color === english
nareshit # variable
'nareshit' #english

# %%
str1='nareshit' # string value inside single quotes
str1
# Out:
# 'nareshit'

# %%
str2="nareshit"  #even with double inverted comma 
str2     #python by default gives ans in string only
# Out:
# 'nareshit'

# %%
str3='nareshit" 
str3   
#this wrong will give error
# Started with single quote.
# Ended with double quote.
# Python gets confused.
# opening and closing quotes must match
# Out:
#   Cell In[13], line 1
#     str3='nareshit"
#          ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
type(str1)
# Out:
# str

# %%
'I like "python"'
# Out:
# 'I like "python"'

# %%
print('I like "python"')
# Out:
# I like "python"

# %%
"I like 'python'"
# Out:
# "I like 'python'"

# %%
print("I like 'python'")
# Out:
# I like 'python'

# %%
"I like "python"" 
# string should be in red that is why we get error
# use single quotes outside if double quotes are inside
# Out:
#   Cell In[20], line 1
#     "I like "python""
#              ^
# SyntaxError: invalid syntax

# %%
'Hi "good" morning'
"Hi 'good' morning"  #both are correct
# Out:
# "Hi 'good' morning"

# %%
type('')
# Out:
# str

# %%
type('a')
# Out:
# str

# %%
'' # how many characters-->0
'a' # how many characters-->1

# %% [markdown]
# **4. len()**

# %% [markdown]
# Used to count characters.

# %%
len('apple')
# Out:
# 5

# %%
len('')
# Out:
# 0

# %%
len(' ')  # spaces are counted as characters
# Out:
# 1

# %%
len(''),len('a'),len('apple')
# Out:
# (0, 1, 5)

# %%
len(' '),len('  ')
# Out:
# (1, 2)

# %%
print('pune')
# Out:
# pune

# %%
print('pune')
print('pune   ')
# Out:
# pune
# pune

# %%
'hyderabad'
"hyderabad"
'hyderabad"  #wrong
'I like "python"'
"I like 'python'"
len('') #0
len('a') #1
len(' ') #1

# %% [markdown]
# **Doc String**

# %% [markdown]
# - we can able to write story in jupyter markdown
#
# - we can not write story as markdown in vscode
#
# - we can write the story by using **triple quotes**
#
# - this is called as **doc string**
#
# - so if anyone is using triple quotes means they are conveying information
#
# - A multi-line string written using triple quotes.

# %%
"""Hello im good
Im learning python
Its very intresting"""   # triple quotes are used for multiline strings/docstrings
# Out:
# 'Hello im good\nIm learning python\nIts very intresting'

# %%
print("""Hello im good
Im learning python
Its very intresting""")
# Out:
# Hello im good
# Im learning python
# Its very intresting

# %% [markdown]
# **5. Boolean**

# %%
# A datatype having only two values.

# True
# False

# Interview Definition:- Boolean is a datatype that represents logical values True or False.

# %%
type(True)
# Out:
# bool

# %%
type(False)
# Out:
# bool

# %%
true

# Error: NameError
# Why?
# Python keywords are:
# True
# False
# Capital T and Capital F.
# True and False are case sensitive
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 true
#
# NameError: name 'true' is not defined

# %%
True ==== ON === 1
False === OFF == 0

# %%
10==10
# Out:
# True

# %% [markdown]
# **= vs ==**

# %%
# = :- Store value(assignment operator)

# == :- Ask question(comparison operator)

# %%
10=10 # wrong
a=10  # assign the value 10 in a  var: a
a==10 # asking qn comparision

# %%
number=100
number==100  # 100==100
# Out:
# True

# %%
100==100
# Out:
# True

# %%
n1=100
n1==100
# Out:
# True

# %%
# Session Summary

# If you remember only 5 things from this session, remember:

# Data Type = Type of data stored
# int = whole number
# float = decimal number
# str = text inside quotes
# bool = True or False
# = stores value
# == compares values
